# %%
from src.DataTransformer import TecanDataTransformer
from src.Wellplate import Wellplate
from src.Experiment import Experiment

# %%
#load the data
datapath = ["../data/2023-12-13_task_plate_read_data_rep1.csv",
            "../data/2023-12-13_task_plate_read_data_rep2.csv",
            "../data/2023-12-13_task_plate_read_data_rep3.csv",
            "../data/2023-12-13_task_plate_read_data_rep4.csv",
            "../data/2023-12-13_task_plate_read_data_rep5.csv"
           ]

# %%
well_datas = [] 
for path in datapath: 
    initial_data = TecanDataTransformer.load_data(path)
    transformed_data = TecanDataTransformer.transform_data(initial_data)
    well_datas.append(TecanDataTransformer.get_transformed_data(transformed_data))

# %%
experiment_data = [] 
layout = (16,24)
for data in well_datas:
    experiment_data.append(Wellplate(layout,data))
# Out:
# /home/bichar4/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/bichar4/.local/lib/python3.8/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/bichar4/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/bichar4/.local/lib/python3.8/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/bichar4/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# ...

# %%
experiment_1 = Experiment(experiment_data)

# %%
experiment_1.validate_same_layout()
# Out:
# True

# %%
experiment_1.plot_combined_data()

# %%
experiment_1.plot_combined_data(shared_y= True)
