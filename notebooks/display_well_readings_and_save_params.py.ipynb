# %%
from src.DataTransformer import TecanDataTransformer
from src.Wellplate import Wellplate

# %%
data_path = "../data/2023-12-13_task_plate_read_data_rep1.csv"

# %%
#transform our data suitable for the wellplate 
initial_data = TecanDataTransformer.load_data(data_path)
transformed_data = TecanDataTransformer.transform_data(initial_data)
well_data = TecanDataTransformer.get_transformed_data(transformed_data)

# %%
well_data
# Out:
# Cycle Nr.  Time [s]      A1      A2      A3      A4      A5      A6      A7  \
# 0               0.0  0.0909  0.1427  0.2582  0.1681  0.1532  0.1618  0.1656
# 1             133.6  0.0910  0.1436  0.2587  0.1696  0.1534  0.1621  0.1657
# 2             267.2  0.0907  0.1428  0.2562  0.1681  0.1527  0.1617  0.1650
# 3             400.9  0.0907  0.1438  0.2558  0.1682  0.1519  0.1611  0.1642
# 4             534.5  0.0908  0.1432  0.2543  0.1676  0.1522  0.1604  0.1641
# ..              ...     ...     ...     ...     ...     ...     ...     ...
# 476         63608.1  0.0906  0.1437  0.6326  0.6680  0.6862  0.6953  0.6837
# 477         63741.7  0.0906  0.1436  0.6325  0.6676  0.6856  0.6921  0.6846
# 478         63875.5  0.0905  0.1423  0.6319  0.6669  0.6851  0.6955  0.6856
# 479         64009.1  0.0905  0.1426  0.6310  0.6665  0.6844  0.6961  0.6850
# 480             NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
# Cycle Nr.      A8      A9  ...     P15     P16     P17     P18     P19  \
# 0          0.1452  0.1656  ...  0.1692  0.1763  0.1810  0.1722  0.1777
# 1          0.1453  0.1656  ...  0.1689  0.1759  0.1820  0.1736  0.1784
# 2          0.1448  0.1647  ...  0.1689  0.1751  0.1817  0.1732  0.1776
# 3          0.1446  0.1645  ...  0.1686  0.1752  0.1833  0.1741  0.1789
# 4          0.1443  0.1635  ...  0.1684  0.1750  0.1840  0.1749  0.1788
# ..            ...     ...  ...     ...     ...     ...     ...     ...
# 476        0.6826  0.7020  ...  0.5168  0.5054  0.4769  0.4473  0.4539
# 477        0.6829  0.7016  ...  0.5161  0.5060  0.4775  0.4482  0.4549
# 478        0.6823  0.7013  ...  0.5158  0.5058  0.4773  0.4492  0.4560
# 479        0.6821  0.7004  ...  0.5148  0.5059  0.4774  0.4492  0.4567
# 480           NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
#
# Cycle Nr.     P20     P21     P22     P23     P24
# 0          0.1805  0.1833  0.1551  0.1701  0.1928
# 1          0.1815  0.1837  0.1564  0.1719  0.1929
# 2          0.1800  0.1825  0.1556  0.1715  0.1939
# 3          0.1818  0.1839  0.1566  0.1725  0.1947
# 4          0.1814  0.1843  0.1569  0.1740  0.1953
# ..            ...     ...     ...     ...     ...
# 476        0.4038  0.4246  0.3258  0.3355  0.3673
# 477        0.4050  0.4259  0.3269  0.3359  0.3685
# 478        0.4062  0.4267  0.3277  0.3365  0.3697
# 479        0.4067  0.4273  0.3288  0.3362  0.3695
# 480           NaN     NaN     NaN     NaN     NaN
#
# [481 rows x 385 columns]

# %%
well_plate_rep_1 = Wellplate((16,24),well_data,'repetition_one')
# Out:
# /home/bichar4/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/bichar4/.local/lib/python3.8/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/bichar4/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/bichar4/.local/lib/python3.8/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
well_plate_rep_1.plot_raw_data()

# %%
#save the growth params to a file 
output_path = "/home/bichar4/Desktop/Biomedical/plate_reader_visualizer/OD-growth-params/results" + "2023-12-13_task_plate_read_data_rep1.csv"
well_plate_rep_1.output_csv(output_path)
